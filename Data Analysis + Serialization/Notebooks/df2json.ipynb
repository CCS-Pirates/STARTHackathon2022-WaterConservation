# %%
import pandas as pd
import json

# %%
fpath = "/content/drive/MyDrive/Start Hackaton Datasets/for_json/Santa Rosa Monthly Water Consumption.xlsx"
df = pd.read_excel(fpath)

# %%
df
# Out:
#          Date  Monthly Water Consumption (in cubic meters)    Barangay
# 0  2016-01-31                                 1.597128e+08  Santa Rosa
# 1  2016-02-29                                 1.197846e+08  Santa Rosa
# 2  2016-03-31                                 1.796769e+08  Santa Rosa
# 3  2016-04-30                                 1.397487e+08  Santa Rosa
# 4  2016-05-31                                 1.597128e+08  Santa Rosa
# 5  2016-06-30                                 1.597128e+08  Santa Rosa
# 6  2016-07-31                                 1.597128e+08  Santa Rosa
# 7  2016-08-31                                 7.985640e+07  Santa Rosa
# 8  2016-09-30                                 3.593538e+08  Santa Rosa
# 9  2016-10-31                                 9.982050e+07  Santa Rosa
# 10 2016-11-30                                 7.985640e+07  Santa Rosa
# 11 2016-12-31                                 2.994615e+08  Santa Rosa
# ...

# %%
result = df.to_json(orient="table")
parsed = json.loads(result)

json_object = json.dumps(parsed, indent=4)

# %%
with open("santa_rosa.json", "w") as outfile:
    json.dump(parsed, outfile)
